# %%
import json
import csv

# Read the JSON file
with open('output.json', 'r') as file:
    transcript = json.load(file)

# Function to break down the transcript into 30-second chunks
def break_into_chunks(transcript, chunk_duration=30):
    chunks = []
    current_chunk = []
    current_duration = 0.0

    for segment in transcript:
        speaker = segment['speaker']
        text = segment['text']
        start_time = segment['start_time']
        end_time = segment['end_time']
        duration = end_time - start_time

        if current_duration + duration <= chunk_duration:
            current_chunk.append({
                'speaker': speaker,
                'text': text,
                'start_time': start_time,
                'end_time': end_time
            })
            current_duration += duration
        else:
            chunks.append(current_chunk)
            current_chunk = [{
                'speaker': speaker,
                'text': text,
                'start_time': start_time,
                'end_time': end_time
            }]
            current_duration = duration

    if current_chunk:
        chunks.append(current_chunk)

    return chunks

# Break the transcript into chunks
chunks = break_into_chunks(transcript)

# Write the chunks to a CSV file
with open('transcript_chunks.csv', 'w', newline='') as csvfile:
    fieldnames = ['chunk_index', 'speaker', 'text', 'start_time', 'end_time']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

    writer.writeheader()
    for i, chunk in enumerate(chunks):
        for segment in chunk:
            writer.writerow({
                'chunk_index': i,
                'speaker': segment['speaker'],
                'text': segment['text'],
                'start_time': segment['start_time'],
                'end_time': segment['end_time']
            })

print('Transcript has been broken into 30-second chunks and saved to transcript_chunks.csv')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-ef6ce31fa4f2> in <cell line: 45>()
#      43
#      44 # Break the transcript into chunks
# ---> 45 chunks = break_into_chunks(transcript)
#      46
#      47 # Write the chunks to a CSV file
#
# <ipython-input-1-ef6ce31fa4f2> in break_into_chunks(transcript, chunk_duration)
#      13
#      14     for segment in transcript:
# ---> 15         speaker = segment['speaker']
#      16         text = segment['text']
#      17         start_time = segment['start_time']
#
# TypeError: string indices must be integers

# %%
import json
import csv

# Read the JSON file
with open('output.json', 'r') as file:
    transcript = json.load(file)

# Function to break down the transcript into 30-second chunks
def break_into_chunks(transcript, chunk_duration=30):
    chunks = []
    current_chunk = []
    current_duration = 0.0

    for segment in transcript:
        speaker = segment["speaker"]
        text = segment['text']
        start_time = segment['start_time']
        end_time = segment['end_time']
        duration = end_time - start_time

        if current_duration + duration <= chunk_duration:
            current_chunk.append({
                'speaker': speaker,
                'text': text,
                'start_time': start_time,
                'end_time': end_time
            })
            current_duration += duration
        else:
            chunks.append(current_chunk)
            current_chunk = [{
                'speaker': speaker,
                'text': text,
                'start_time': start_time,
                'end_time': end_time
            }]
            current_duration = duration

    if current_chunk:
        chunks.append(current_chunk)

    return chunks

# Break the transcript into chunks
chunks = break_into_chunks(transcript)

# Write the chunks to a CSV file
with open('transcript_chunks.csv', 'w', newline='') as csvfile:
    fieldnames = ['chunk_index', 'speaker', 'text', 'start_time', 'end_time']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

    writer.writeheader()
    for i, chunk in enumerate(chunks):
        for segment in chunk:
            writer.writerow({
                'chunk_index': i,
                'speaker': segment['speaker'],
                'text': segment['text'],
                'start_time': segment['start_time'],
                'end_time': segment['end_time']
            })

print('Transcript has been broken into 30-second chunks and saved to transcript_chunks.csv')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-88fd7b6f33f4> in <cell line: 45>()
#      43
#      44 # Break the transcript into chunks
# ---> 45 chunks = break_into_chunks(transcript)
#      46
#      47 # Write the chunks to a CSV file
#
# <ipython-input-4-88fd7b6f33f4> in break_into_chunks(transcript, chunk_duration)
#      13
#      14     for segment in transcript:
# ---> 15         speaker = segment["speaker"]
#      16         text = segment['text']
#      17         start_time = segment['start_time']
#
# TypeError: string indices must be integers

# %%
import json
import csv

# Read the JSON file
with open('output.json', 'r') as file:
    transcript = json.load(file)

# Function to break down the transcript into 30-second chunks
def break_into_chunks(transcript, chunk_duration=30):
    chunks = []
    current_chunk = []
    current_duration = 0.0

    for segment in transcript:
        speaker = segment["speaker"] # Changed this line to access the dictionary key correctly
        text = segment['text']
        start_time = segment['start_time']
        end_time = segment['end_time']
        duration = end_time - start_time

        if current_duration + duration <= chunk_duration:
            current_chunk.append({
                'speaker': speaker,
                'text': text,
                'start_time': start_time,
                'end_time': end_time
            })
            current_duration += duration
        else:
            chunks.append(current_chunk)
            current_chunk = [{
                'speaker': speaker,
                'text': text,
                'start_time': start_time,
                'end_time': end_time
            }]
            current_duration = duration

    if current_chunk:
        chunks.append(current_chunk)

    return chunks

# Break the transcript into chunks
chunks = break_into_chunks(transcript)

# Write the chunks to a CSV file
with open('transcript_chunks.csv', 'w', newline='') as csvfile:
    fieldnames = ['chunk_index', 'speaker', 'text', 'start_time', 'end_time']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

    writer.writeheader()
    for i, chunk in enumerate(chunks):
        for segment in chunk:
            writer.writerow({
                'chunk_index': i,
                'speaker': segment['speaker'],
                'text': segment['text'],
                'start_time': segment['start_time'],
                'end_time': segment['end_time']
            })

print('Transcript has been broken into 30-second chunks and saved to transcript_chunks.csv')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-304c59630bc6> in <cell line: 45>()
#      43
#      44 # Break the transcript into chunks
# ---> 45 chunks = break_into_chunks(transcript)
#      46
#      47 # Write the chunks to a CSV file
#
# <ipython-input-5-304c59630bc6> in break_into_chunks(transcript, chunk_duration)
#      13
#      14     for segment in transcript:
# ---> 15         speaker = segment["speaker"] # Changed this line to access the dictionary key correctly
#      16         text = segment['text']
#      17         start_time = segment['start_time']
#
# TypeError: string indices must be integers

# %%
import json
import csv

# Read the JSON file
with open('output.json', 'r') as file:
    transcript = json.load(file)

# Check the type and structure of the transcript
print(type(transcript))
if isinstance(transcript, list):
    if len(transcript) > 0:
        print(type(transcript[0]))
        print(transcript[0])
    else:
        print("The transcript list is empty.")
else:
    print("The transcript is not a list.")

# Function to break down the transcript into 30-second chunks
def break_into_chunks(transcript, chunk_duration=30):
    chunks = []
    current_chunk = []
    current_duration = 0.0

    for segment in transcript:
        speaker = segment['speaker']
        text = segment['text']
        start_time = segment['start_time']
        end_time = segment['end_time']
        duration = end_time - start_time

        if current_duration + duration <= chunk_duration:
            current_chunk.append({
                'speaker': speaker,
                'text': text,
                'start_time': start_time,
                'end_time': end_time
            })
            current_duration += duration
        else:
            chunks.append(current_chunk)
            current_chunk = [{
                'speaker': speaker,
                'text': text,
                'start_time': start_time,
                'end_time': end_time
            }]
            current_duration = duration

    if current_chunk:
        chunks.append(current_chunk)

    return chunks

# Only proceed if the transcript is a list of dictionaries
if isinstance(transcript, list) and all(isinstance(segment, dict) for segment in transcript):
    # Break the transcript into chunks
    chunks = break_into_chunks(transcript)

    # Write the chunks to a CSV file
    with open('transcript_chunks.csv', 'w', newline='') as csvfile:
        fieldnames = ['chunk_index', 'speaker', 'text', 'start_time', 'end_time']
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

        writer.writeheader()
        for i, chunk in enumerate(chunks):
            for segment in chunk:
                writer.writerow({
                    'chunk_index': i,
                    'speaker': segment['speaker'],
                    'text': segment['text'],
                    'start_time': segment['start_time'],
                    'end_time': segment['end_time']
                })

    print('Transcript has been broken into 30-second chunks and saved to transcript_chunks.csv')
else:
    print("The transcript data is not in the expected format.")
# Out:
# <class 'dict'>
# The transcript is not a list.
# The transcript data is not in the expected format.

# %%
import json
import csv

# Read the JSON file
with open('output.json', 'r') as file:
    transcript = json.load(file)

# Inspect the dictionary structure
print(transcript.keys())

# Assuming the actual transcript data is within a specific key, like 'segments' or similar
# Replace 'segments' with the actual key from your JSON structure
if 'segments' in transcript:
    segments = transcript['segments']
    print(type(segments))
    if isinstance(segments, list) and len(segments) > 0:
        print(type(segments[0]))
        print(segments[0])

    # Function to break down the transcript into 30-second chunks
    def break_into_chunks(segments, chunk_duration=30):
        chunks = []
        current_chunk = []
        current_duration = 0.0

        for segment in segments:
            speaker = segment['speaker']
            text = segment['text']
            start_time = segment['start_time']
            end_time = segment['end_time']
            duration = end_time - start_time

            if current_duration + duration <= chunk_duration:
                current_chunk.append({
                    'speaker': speaker,
                    'text': text,
                    'start_time': start_time,
                    'end_time': end_time
                })
                current_duration += duration
            else:
                chunks.append(current_chunk)
                current_chunk = [{
                    'speaker': speaker,
                    'text': text,
                    'start_time': start_time,
                    'end_time': end_time
                }]
                current_duration = duration

        if current_chunk:
            chunks.append(current_chunk)

        return chunks

    # Break the transcript into chunks
    chunks = break_into_chunks(segments)

    # Write the chunks to a CSV file
    with open('transcript_chunks.csv', 'w', newline='') as csvfile:
        fieldnames = ['chunk_index', 'speaker', 'text', 'start_time', 'end_time']
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

        writer.writeheader()
        for i, chunk in enumerate(chunks):
            for segment in chunk:
                writer.writerow({
                    'chunk_index': i,
                    'speaker': segment['speaker'],
                    'text': segment['text'],
                    'start_time': segment['start_time'],
                    'end_time': segment['end_time']
                })

    print('Transcript has been broken into 30-second chunks and saved to transcript_chunks.csv')
else:
    print("The transcript data does not contain the expected 'segments' key.")
# Out:
# dict_keys(['dialogue'])
# The transcript data does not contain the expected 'segments' key.

# %%
import json
import csv

# Read the JSON file
with open('output.json', 'r') as file:
    transcript_data = json.load(file)

# Extract the dialogue segments
if 'dialogue' in transcript_data:
    segments = transcript_data['dialogue']
    print(type(segments))
    if isinstance(segments, list) and len(segments) > 0:
        print(type(segments[0]))
        print(segments[0])

    # Function to break down the transcript into 30-second chunks
    def break_into_chunks(segments, chunk_duration=30):
        chunks = []
        current_chunk = []
        current_duration = 0.0

        for segment in segments:
            speaker = segment['speaker']
            text = segment['text']
            start_time = segment['start_time']
            end_time = segment['end_time']
            duration = end_time - start_time

            if current_duration + duration <= chunk_duration:
                current_chunk.append({
                    'speaker': speaker,
                    'text': text,
                    'start_time': start_time,
                    'end_time': end_time
                })
                current_duration += duration
            else:
                chunks.append(current_chunk)
                current_chunk = [{
                    'speaker': speaker,
                    'text': text,
                    'start_time': start_time,
                    'end_time': end_time
                }]
                current_duration = duration

        if current_chunk:
            chunks.append(current_chunk)

        return chunks

    # Break the transcript into chunks
    chunks = break_into_chunks(segments)

    # Write the chunks to a CSV file
    with open('transcript_chunks.csv', 'w', newline='') as csvfile:
        fieldnames = ['chunk_index', 'speaker', 'text', 'start_time', 'end_time']
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

        writer.writeheader()
        for i, chunk in enumerate(chunks):
            for segment in chunk:
                writer.writerow({
                    'chunk_index': i,
                    'speaker': segment['speaker'],
                    'text': segment['text'],
                    'start_time': segment['start_time'],
                    'end_time': segment['end_time']
                })

    print('Transcript has been broken into 30-second chunks and saved to transcript_chunks.csv')
else:
    print("The transcript data does not contain the expected 'dialogue' key.")
# Out:
# <class 'list'>
# <class 'dict'>
# {'speaker': 'SPEAKER_01', 'text': 'So, Aaron, in your email you said you wanted to talk about the exam.', 'start_time': 0.318, 'end_time': 4.1819999999999995}
# Transcript has been broken into 30-second chunks and saved to transcript_chunks.csv

# %%
pip install librosa soundfile

# %%
import librosa
import soundfile as sf
import os

# Load the large audio file
audio_file = 'test.wav'
y, sr = librosa.load(audio_file, sr=None)

# Directory to save the audio chunks
output_dir = 'audio_chunks'
os.makedirs(output_dir, exist_ok=True)

# Duration of each chunk in seconds
chunk_duration = 30

# Calculate the number of samples per chunk
samples_per_chunk = chunk_duration * sr

# Total number of chunks
num_chunks = (len(y) + samples_per_chunk - 1) // samples_per_chunk

for i in range(num_chunks):
    start_sample = i * samples_per_chunk
    end_sample = min((i + 1) * samples_per_chunk, len(y))
    chunk = y[start_sample:end_sample]

    # Define the chunk file name
    chunk_filename = os.path.join(output_dir, f'chunk_{i+1:03d}.wav')

    # Save the chunk as a WAV file
    sf.write(chunk_filename, chunk, sr)
    print(f'Saved {chunk_filename}')

print('All chunks have been saved.')
# Out:
# Saved audio_chunks/chunk_001.wav
# All chunks have been saved.

# %%
import json
import os
import librosa
import soundfile as sf

# Load the JSON file
with open('output.json', 'r') as file:
    transcript_data = json.load(file)

# Extract the dialogue segments
if 'dialogue' in transcript_data:
    segments = transcript_data['dialogue']
else:
    raise ValueError("The transcript data does not contain the expected 'dialogue' key.")

# Load the large audio file
audio_file = 'test.wav'
y, sr = librosa.load(audio_file, sr=None)

# Directory to save the audio chunks
output_dir = 'audio_chunks'
os.makedirs(output_dir, exist_ok=True)

# Function to extract and save audio chunks based on timestamps
def save_audio_chunks(segments, y, sr, output_dir):
    for i, segment in enumerate(segments):
        start_time = segment['start_time']
        end_time = segment['end_time']

        start_sample = int(start_time * sr)
        end_sample = int(end_time * sr)

        chunk = y[start_sample:end_sample]

        # Define the chunk file name
        chunk_filename = os.path.join(output_dir, f'chunk_{i+1:03d}.wav')

        # Save the chunk as a WAV file
        sf.write(chunk_filename, chunk, sr)
        print(f'Saved {chunk_filename}')

# Save the audio chunks
save_audio_chunks(segments, y, sr, output_dir)
# Out:
# Saved audio_chunks/chunk_001.wav
# Saved audio_chunks/chunk_002.wav
# Saved audio_chunks/chunk_003.wav
# Saved audio_chunks/chunk_004.wav
# Saved audio_chunks/chunk_005.wav
# Saved audio_chunks/chunk_006.wav
# Saved audio_chunks/chunk_007.wav
# Saved audio_chunks/chunk_008.wav
# Saved audio_chunks/chunk_009.wav
# Saved audio_chunks/chunk_010.wav

# %%
import json
import os
import librosa
import soundfile as sf
import csv

# Load the JSON file
with open('output.json', 'r') as file:
    transcript_data = json.load(file)

# Extract the dialogue segments
if 'dialogue' in transcript_data:
    segments = transcript_data['dialogue']
else:
    raise ValueError("The transcript data does not contain the expected 'dialogue' key.")

# Load the large audio file
audio_file = 'test.wav'
y, sr = librosa.load(audio_file, sr=None)

# Directory to save the audio chunks
output_dir = 'audio_chunks'
os.makedirs(output_dir, exist_ok=True)

# CSV file to save the mappings
csv_file = 'audio_transcript_mapping.csv'

# Function to extract and save audio chunks based on timestamps and create mappings
def save_audio_chunks_and_create_mapping(segments, y, sr, output_dir, csv_file):
    with open(csv_file, mode='w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(['chunk_index', 'audio_chunk_path', 'speaker', 'text', 'start_time', 'end_time'])

        for i, segment in enumerate(segments):
            start_time = segment['start_time']
            end_time = segment['end_time']

            start_sample = int(start_time * sr)
            end_sample = int(end_time * sr)

            chunk = y[start_sample:end_sample]

            # Define the chunk file name
            chunk_filename = os.path.join(output_dir, f'chunk_{i+1:03d}.wav')

            # Save the chunk as a WAV file
            sf.write(chunk_filename, chunk, sr)
            print(f'Saved {chunk_filename}')

            # Write the mapping to the CSV file
            writer.writerow([i+1, chunk_filename, segment['speaker'], segment['text'], start_time, end_time])

# Save the audio chunks and create the CSV mapping file
save_audio_chunks_and_create_mapping(segments, y, sr, output_dir, csv_file)

print('Audio chunks have been saved and mapped to transcript in CSV file.')
# Out:
# Saved audio_chunks/chunk_001.wav
# Saved audio_chunks/chunk_002.wav
# Saved audio_chunks/chunk_003.wav
# Saved audio_chunks/chunk_004.wav
# Saved audio_chunks/chunk_005.wav
# Saved audio_chunks/chunk_006.wav
# Saved audio_chunks/chunk_007.wav
# Saved audio_chunks/chunk_008.wav
# Saved audio_chunks/chunk_009.wav
# Saved audio_chunks/chunk_010.wav
# Audio chunks have been saved and mapped to transcript in CSV file.
